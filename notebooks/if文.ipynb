# %%
# 練習1
x = 80

if (x >= 60):
  print("合格")
else:
  print("不合格")
# Out:
# 合格

# %%
# 練習2
x = int(input("Input x: "))

if (x >= 60):
  print("合格")
else:
  print("不合格")
# Out:
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# <ipython-input-2-5a3f0f548c1f> in <module>
#       1 # 練習2
# ----> 2 x = int(input("Input x: "))
#       3
#       4 if (x >= 60):
#       5   print("合格")
#
# ~\AppData\Roaming\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     853         if not self._allow_stdin:
#     854             raise StdinNotImplementedError(
# --> 855                 "raw_input was called, but this frontend does not support input requests."
#     856             )
#     857         return self._input_request(str(prompt),
#
# StdinNotImplementedError: raw_input was called, but this frontend does not support input requests.

# %%
# 練習3
x = int(input("Input x: "))

if (90 <= x):
  print("秀")
elif (80 <= x < 90):
  print("優")
elif (70 <= x < 80):
  print("良")
elif (60 <= x < 70):
  print("可")
else: print("不可")

# %%
# 最適化済み
x: int = input("Input x: ") or 0

try:
  x = int(x)
except ValueError as err:
  raise TypeError("A parameter, 'x' must be Integer.")

if (90 <= x):
  print("秀")
elif (80 <= x < 90):
  print("優")
elif (70 <= x < 80):
  print("良")
elif (60 <= x < 70):
  print("可")
else: print("不可")
