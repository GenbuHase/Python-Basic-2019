# %%
print(1 + 2)
# Out:
# 3

# %%
print(10 * 2)
# Out:
# 20

# %%
print(10 / 2)
# Out:
# 5.0

# %%
print(11 % 2)
# Out:
# 1

# %%
print(2**10)
# Out:
# 1024

# %%
print(2 == 2)
# Out:
# True

# %%
print(2 != 2)
# Out:
# False

# %%
print(2 > 2)
# Out:
# False

# %%
print(2 >= 2)
# Out:
# True

# %%
i = 100
print(i%2 == 0)
# Out:
# True

# %%
i = 101
print(i%2 == 1)
# Out:
# True
